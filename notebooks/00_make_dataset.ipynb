# %% [markdown]
# # Building the dataset for the Carbon Footprint Estimation Model

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from carbon.dataset import build_table
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Product Table

# %% [markdown]
# ### Idemat

# %%
df_idemat = pd.read_excel('../data/external/Idemat_2024-V2-2.xlsx', sheet_name='Idemat2024')
df1 = build_table(df_idemat, 'idemat')
# Out:
# 2024-08-09 22:51:25.512 | INFO     | carbon.dataset:build_table:7 - Building dataset for idemat
# 2024-08-09 22:51:25.513 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 0: 2 validation errors for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# carbon_footprint
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='footprint', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# 2024-08-09 22:51:25.514 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1: 2 validation errors for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# carbon_footprint
#   Input should be a valid number, unable to parse string as a number [type=float_parsing, input_value='kg CO2 equiv.', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.8/v/float_parsing
# 2024-08-09 22:51:25.514 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.515 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 3: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.516 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 8: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.517 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 22: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.518 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 27: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.519 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 44: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.520 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 45: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.522 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 59: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.523 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 60: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.524 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 66: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.525 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 75: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.526 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 79: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.526 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 90: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.528 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 126: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.530 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 163: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.534 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 224: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.535 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 226: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.536 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 231: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.537 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 255: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.538 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 267: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.539 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 274: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.540 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 278: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.541 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 283: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.542 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 300: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.543 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 316: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.543 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 317: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.544 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 321: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.545 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 324: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.545 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 329: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.546 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 332: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.547 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 336: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.548 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 345: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.548 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 350: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.549 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 351: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.550 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 372: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.551 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 388: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.552 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 389: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.553 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 393: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.554 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 394: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.555 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 406: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.556 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 422: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.558 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 433: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.559 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 438: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.559 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 440: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.560 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 444: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.561 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 453: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.562 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 466: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.563 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 468: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.563 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 472: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.564 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 473: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.564 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 475: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.565 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 481: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.566 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 489: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.567 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 490: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.568 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 496: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.568 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 497: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.569 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 502: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.570 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 511: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.573 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 570: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.573 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 575: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.574 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 584: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.575 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 589: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.576 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 594: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.577 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 612: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.578 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 617: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.578 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 624: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.579 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 629: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.580 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 630: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.583 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 686: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.584 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 698: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.585 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 713: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.587 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 735: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.590 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 760: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.591 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 771: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.592 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 785: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.593 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 789: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.594 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 795: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.595 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 803: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.596 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 804: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.597 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 817: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.598 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 831: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.599 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 835: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.600 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 838: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.601 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 839: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.602 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 850: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.604 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 876: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.605 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 889: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.607 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 922: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.608 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 937: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.610 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 954: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.611 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 955: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.613 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 977: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.614 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1007: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.615 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1008: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.616 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1011: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.616 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1012: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.617 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1034: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.619 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1066: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.621 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1102: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.623 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1130: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.625 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1162: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.627 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1193: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.628 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1204: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.630 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1221: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.630 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1222: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.631 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1230: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.632 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1233: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.633 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1265: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.635 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1297: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.636 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1298: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.642 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1491: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.643 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1492: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.644 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1506: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.646 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1539: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.648 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1570: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.651 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1622: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.651 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1623: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.652 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1631: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.652 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1632: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.653 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1639: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.654 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1642: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.655 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1646: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.656 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1653: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.657 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1662: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.657 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1663: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.658 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1668: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.658 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1672: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.659 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1683: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.660 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1688: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.662 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1723: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.663 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1730: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.664 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1740: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.664 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1745: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.665 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1746: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.666 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1755: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.667 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1769: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.668 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1795: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.669 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1799: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.671 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1817: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.671 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1825: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.672 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1834: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.673 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1848: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.674 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1874: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.675 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1878: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.676 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1896: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.677 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1900: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.678 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1909: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.678 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1915: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.680 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1940: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.681 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1944: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.682 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1962: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.683 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1966: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.683 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1979: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.684 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 1992: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.685 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2007: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.687 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2031: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.689 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2051: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.690 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2052: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.690 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2055: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.691 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2061: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.692 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2072: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.693 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2075: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.693 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2077: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.695 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2102: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.696 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2113: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.697 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2121: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.699 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2146: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.700 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2150: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.700 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2156: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.702 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2162: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.702 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2170: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.703 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2172: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.704 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2189: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.706 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2205: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.707 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2214: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.708 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2218: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.709 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2220: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.710 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2232: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.711 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2240: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.713 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2264: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.714 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2281: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.716 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2289: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.717 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2302: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.718 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2306: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.718 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2307: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.723 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2410: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.725 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2411: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.726 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2428: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.726 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2430: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type
# 2024-08-09 22:51:25.727 | ERROR    | carbon.dataset:build_table:18 - Validation error in row 2438: 1 validation error for ProductDatasetEntry
# product
#   Input should be a valid string [type=string_type, input_value=nan, input_type=float]
#     For further information visit https://errors.pydantic.dev/2.8/v/string_type

# %%
df1.head()
# Out:
#                                         product  carbon_footprint  source
# 0   Leather Chrome tanning, hides from Argentia         15.920720  idemat
# 1  Leather Vegetable tanning, hides from Europe         17.976909  idemat
# 2    Wool (Australia, transported to Rotterdam)         78.077451  idemat
# 3                        Wool at farm Australia         77.757541  idemat
# 4                 Crude palm kernel oil refined          0.946775  idemat

# %% [markdown]
# ### Carbon Catalogue

# %%
df_catalogue = pd.read_excel('../data/external/PublicTablesForCarbonCatalogueDataDescriptor_v30Oct2021.xlsx', sheet_name='Product Level Data')
df2 = build_table(df_catalogue, 'catalogue')
# Out:
# 2024-08-09 22:56:40.214 | INFO     | carbon.dataset:build_table:7 - Building dataset for catalogue

# %%
df2.head()
# Out:
#                                              product  carbon_footprint  \
# 0  Frosted Flakes(R) Cereal - Frosted Flakes(R), ...              2.00
# 1  Frosted Flakes, 23 oz, produced in Lancaster, ...              2.00
# 2     Office Chair - Field not included in 2013 data             72.54
# 3               Multifunction Printers - bizhub C458           1488.00
# 4               Multifunction Printers - bizhub C558           1818.00
#
#       source
# 0  catalogue
# 1  catalogue
# 2  catalogue
# 3  catalogue
# 4  catalogue

# %% [markdown]
# ### RIVM

# %%
df3 = pd.read_excel('../data/interim/datasetRIVM.xlsx')
df3.columns = ['product', 'carbon_footprint', 'source']
df3.head()
# Out:
#                      product  carbon_footprint source
# 0    Pre -fried frozen fries          6.152581   RIVM
# 1  Mashed potatoes, homemade          1.087099   RIVM
# 2      Potatoes without peel          0.923141   RIVM
# 3              Beer (bottle)          0.707146   RIVM
# 4                        Gin          2.487465   RIVM

# %% [markdown]
# ### Merge

# %%
df_products = pd.concat([df1, df2, df3], ignore_index=True)
df_products
# Out:
#                                            product  carbon_footprint  source
# 0      Leather Chrome tanning, hides from Argentia         15.920720  idemat
# 1     Leather Vegetable tanning, hides from Europe         17.976909  idemat
# 2       Wool (Australia, transported to Rotterdam)         78.077451  idemat
# 3                           Wool at farm Australia         77.757541  idemat
# 4                    Crude palm kernel oil refined          0.946775  idemat
# ...                                            ...               ...     ...
# 3374                           Roasted minced meat          8.227510    RIVM
# 3375                                       Sausage         15.182344    RIVM
# 3376                                      Sandwich          6.534396    RIVM
# 3377                                    Ossenworst         24.097559    RIVM
# 3378                               Cervelaat Worst         14.735792    RIVM
#
# [3379 rows x 3 columns]

# %%
df_products.to_excel('../data/processed/product.xlsx')

# %% [markdown]
# ## Industry Table

# %% [markdown]
# ### MRIO

# %%
df_mrio = pd.read_excel('../data/external/SWC_MRIO_Emissions_Factors_2018-2022_v1.0.xlsx', sheet_name='Total_EF_PP_2022_CID', skiprows=2)
df_mrio = (df_mrio
           .drop(['SIC Code'], axis=1)
           .rename(columns={'Description': 'industry'})
            )
df_mrio.head()
# Out:
#                                             industry  Australia   Austria  \
# 0  Crop And Animal Production, Hunting And Relate...   2.334000  1.201024
# 1                             Forestry And Logging     0.349923  0.180063
# 2                          Fishing And Aquaculture     2.335598  0.366232
# 3                       Mining Of Coal And Lignite     3.159084  3.318450
# 4  Extraction Of Crude Petroleum And Natural Gas ...   1.489419  1.564556
#
#     Belgium    Canada     Chile  Colombia  Costa Rica  Czech Republic  \
# 0  1.543530  1.741256  1.178838  2.460617    1.540543        1.414710
# 1  0.231412  0.261056  0.176736  0.368906    0.230965        0.212099
# 2  0.807716  1.282297  1.299419  1.295168    1.156190        0.621587
# 3  2.493753  3.989739  4.330726  3.208149    2.875992        7.056656
# 4  1.175734  1.881049  2.041815  1.512552    1.355949        3.327014
#
#     Denmark  ...      Peru  Philippines   Romania  Russian Federation  \
# 0  1.561344  ...  1.165925     1.580857  1.401421            1.806335
# 1  0.234083  ...  0.174800     0.237009  0.210107            0.270813
# 2  0.493183  ...  0.602762     0.682720  0.575020            2.044040
# 3  2.086219  ...  3.589356     4.554701  4.941724            4.485118
# 4  0.983593  ...  1.692280     2.147413  2.329883            2.114606
#
#    Saudi Arabia  Singapore  South Africa  Thailand   Tunisia  Viet Nam
# 0      0.955992   1.058443      3.309331  2.102699  1.603964  2.687248
# 1      0.143326   0.158686      0.496149  0.315245  0.240473  0.402883
# 2      1.452257   1.178576      1.696874  2.168330  1.047297  2.972228
# 3      3.158024   6.082992     11.642101  4.847991  7.623694  5.348372
# 4      1.488919   2.867959      5.488921  2.285691  3.594356  2.521606
#
# [5 rows x 66 columns]

# %%
# unpivot the table
df_mrio = df_mrio.melt(id_vars = ['industry'],
                       var_name = 'country',
                       value_name = 'carbon_footprint_per_USD')
df_mrio['source'] = 'mrio'

# %%
df_mrio.head()
# Out:
#                                             industry    country  \
# 0  Crop And Animal Production, Hunting And Relate...  Australia
# 1                             Forestry And Logging    Australia
# 2                          Fishing And Aquaculture    Australia
# 3                       Mining Of Coal And Lignite    Australia
# 4  Extraction Of Crude Petroleum And Natural Gas ...  Australia
#
#    carbon_footprint_per_USD source
# 0                  2.334000   mrio
# 1                  0.349923   mrio
# 2                  2.335598   mrio
# 3                  3.159084   mrio
# 4                  1.489419   mrio

# %%
df_mrio.to_excel('../data/processed/industry.xlsx')
